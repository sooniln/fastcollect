// %%
%useLatestDescriptors
%use dataframe
%use kandy

// %%
// > memory.txt is expected to hold the ouput of "./gradlew runSplitMemoryMeasurement"
val memory = DataFrame.read("split_memory.csv")
// Out:
// kotlin-logging: initializing... active logger factory: Slf4jLoggerFactory

// %%
private enum class CollectionType(val text: String, val sizeMultiplier: Int = 1) {
    LIST("list"),
    SET("set"),
    MAP("map", 2)
}

private val elementsSize = 1000000 * 4 // benchmark ran against 1 million ints
private val collectionType = CollectionType.SET

memory
    .filter { "collection"<String>().startsWith(collectionType.text) }
    .take(100)
    .update("collection").cast<String>().with { it.removePrefix(collectionType.text) }
    .convert("numCollections").cast<Int>().with { "${it} x ${1000000 / it}" }
    .convert("totalBytes").cast<Int>().with { (it - collectionType.sizeMultiplier*elementsSize) / (1024.0 * 1024.0) }
    .plot {
        bars {
            x("numCollections") {
                axis.name = "Collection Split (# of Collections x # of Elements)"
            }
            y("totalBytes") {
                axis.name = "Overhead (MB)"
            }
            fillColor("collection") {
                legend.name = ""
                scale = categorical(
                    "FastCollect" to Color.RED,
                    "Fastutil" to Color.BLUE,
                    "KDS" to Color.GREEN,
                    "Kotlin" to Color.PURPLE,
                )
            }
        }
        layout {
            title = "1 Million Elements Collection Split Overhead"
            size = 894 to 800
        }
    }
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='894' height='800' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; padding: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.8.2/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;surmuz&quot; >&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: &quot;FIXED&quot;,
//        height_mode: &quot;FIXED&quot;,
//        width: 894.0,
//        height: 800.0
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById(&quot;surmuz&quot;);
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// &quot;ggtitle&quot;:{
// &quot;text&quot;:&quot;1 Million Elements Collection Split Overhead&quot;
// },
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;numCollections&quot;:[&quot;1000000 x 1&quot;,&quot;1000000 x 1&quot;,&quot;1000000 x 1&quot;,&quot;1000000 x 1&quot;,&quot;500000 x 2&quot;,&quot;500000 x 2&quot;,&quot;500000 x 2&quot;,&quot;500000 x 2&quot;,&quot;250000 x 4&quot;,&quot;250000 x 4&quot;,&quot;250000 x 4&quot;,&quot;250000 x 4&quot;,&quot;200000 x 5&quot;,&quot;200000 x 5&quot;,&quot;200000 x 5&quot;,&quot;200000 x 5&quot;,&quot;125000 x 8&quot;,&quot;125000 x 8&quot;,&quot;125000 x 8&quot;,&quot;125000 x 8&quot;,&quot;100000 x 10&quot;,&quot;100000 x 10&quot;,&quot;100000 x 10&quot;,&quot;100000 x 10&quot;,&quot;62500 x 16&quot;,&quot;62500 x 16&quot;,&quot;62500 x 16&quot;,&quot;62500 x 16&quot;,&quot;50000 x 20&quot;,&quot;50000 x 20&quot;,&quot;50000 x 20&quot;,&quot;50000 x 20&quot;,&quot;40000 x 25&quot;,&quot;40000 x 25&quot;,&quot;40000 x 25&quot;,&quot;40000 x 25&quot;,&quot;31250 x 32&quot;,&quot;31250 x 32&quot;,&quot;31250 x 32&quot;,&quot;31250 x 32&quot;,&quot;25000 x 40&quot;,&quot;25000 x 40&quot;,&quot;25000 x 40&quot;,&quot;25000 x 40&quot;,&quot;20000 x 50&quot;,&quot;20000 x 50&quot;,&quot;20000 x 50&quot;,&quot;20000 x 50&quot;,&quot;15625 x 64&quot;,&quot;15625 x 64&quot;,&quot;15625 x 64&quot;,&quot;
quot;FastCollect&quot;,&quot;Fastutil&quot;,&quot;KDS&quot;,&quot;Kotlin&quot;,&quot;FastCollect&quot;,&quot;Fastutil&quot;,&quot;KDS&quot;,&quot;Kotlin&quot;,&quot;FastCollect&quot;,&quot;Fastutil&quot;,&quot;KDS&quot;,&quot;Kotlin&quot;,&quot;FastCollect&quot;,&quot;Fastutil&quot;,&quot;KDS&quot;,&quot;Kotlin&quot;,&quot;FastCollect&quot;,&quot;Fastutil&quot;,&quot;KDS&quot;,&quot;Kotlin&quot;,&quot;FastCollect&quot;,&quot;Fastutil&quot;,&quot;KDS&quot;,&quot;Kotlin&quot;,&quot;FastCollect&quot;,&quot;Fastutil&quot;,&quot;KDS&quot;,&quot;Kotlin&quot;,&quot;FastCollect&quot;,&quot;Fastutil&quot;,&quot;KDS&quot;,&quot;Kotlin&quot;,&quot;FastCollect&quot;,&quot;Fastutil&quot;,&quot;KDS&quot;,&quot;Kotlin&quot;,&quot;FastCollect&quot;,&quot;Fastutil&quot;,&quot;KDS&quot;,&quot;Kotlin&quot;,&quot;FastCollect&quot;,&quot;Fastutil&quot;,&quot;KDS&quot;,&quot;Kotlin&quot;,&quot;FastCollect&quot;,&quot;Fastutil&quot;,&quot;KDS&quot;,&quot;Kotlin&quot;,&quot;FastCollect&quot;,&quot;Fastutil&quot;,&quot;KDS&quot;,&quot;Kotlin&quot;,&quot;FastCollect&quot;,&quot;Fastutil&quot;,&quot;KDS&quot;,&quot;Kotlin&quot;,&quot;FastCollect&quot;,&quot;Fastutil&quot;,&quot;KDS&quot;,&quot;Kotlin&quot;,&quot;FastCollect&quot;,&quot;Fastutil&quot;,&quot;KDS&quot;,&quot;Kotlin&quot;,&quot;FastCollect&quot;,&quot;Fastutil&quot;,&quot;KDS&quot;,&quot;Kotlin&quot;,&quot;FastCollect&quot;,&quot;Fastutil&quot;,&quot;KDS&quot;,&quot;Kotlin&quot;,&quot;FastCollect&quot;,&quot;Fastutil&quot;,&quot;KDS&quot;,&quot;Kotlin&quot;,&quot;FastCollect&quot;,&quot;Fastutil&quot;,&quot;KDS&quot;,&quot;Kotlin&quot;,&quot;FastCollect&quot;,&quot;Fastutil&quot;,&quot;KDS&quot;,&quot;Kotlin&quot;,&quot;FastCollect&quot;,&quot;Fastutil&quot;,&quot;KDS&quot;,&quot;Kotlin&quot;,&quot;FastCollect&quot;,&quot;Fastutil&quot;,&quot;KDS&quot;,&quot;Kotlin&quot;,&quot;FastCollect&quot;,&quot;Fastutil&quot;,&quot;KDS&quot;,&quot;Kotlin&quot;,&quot;FastCollect&quot;,&quot;Fastutil&quot;,&quot;KDS&quot;,&quot;Kotlin&quot;]
// },
// &quot;ggsize&quot;:{
// &quot;width&quot;:894.0,
// &quot;height&quot;:800.0
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;discrete&quot;:true,
// &quot;name&quot;:&quot;Collection Split (# of Collections x # of Elements)&quot;
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;name&quot;:&quot;Overhead (MB)&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;fill&quot;,
// &quot;values&quot;:

// %%
private enum class CollectionType(val text: String, val prettyName: String)  {
    LIST("emptylist", "List"),
    SET("emptyset", "Set"),
    MAP("emptymap", "Map")
}

private val collectionType = CollectionType.MAP

memory
    .filter { "collection"<String>().startsWith(collectionType.text) }
    .take(100)
    .update("collection").cast<String>().with { it.removePrefix(collectionType.text) }
    .convert("numCollections").cast<Int>().with { "${it} x ${1000000 / it}" }
    .convert("totalBytes").cast<Int>().with { it / (1024.0 * 1024.0) }
    .plot {
        bars {
            x("numCollections") {
                axis.name = ""
                axis.breaks(emptyList())
            }
            y("totalBytes") {
                axis.name = "Overhead (MB)"
            }
            fillColor("collection") {
                legend.name = ""
                scale = categorical(
                    "FastCollect" to Color.RED,
                    "Fastutil" to Color.BLUE,
                    "KDS" to Color.GREEN,
                    "Kotlin" to Color.PURPLE,
                )
            }
        }
        layout {
            title = "1 Million Empty ${collectionType.prettyName}s Overhead"
            size = 894 to 800
        }
    }
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='894' height='800' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; padding: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.8.2/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;OALlYR&quot; >&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: &quot;FIXED&quot;,
//        height_mode: &quot;FIXED&quot;,
//        width: 894.0,
//        height: 800.0
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById(&quot;OALlYR&quot;);
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// &quot;ggtitle&quot;:{
// &quot;text&quot;:&quot;1 Million Empty Maps Overhead&quot;
// },
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;numCollections&quot;:[&quot;1000000 x 1&quot;,&quot;1000000 x 1&quot;,&quot;1000000 x 1&quot;,&quot;1000000 x 1&quot;],
// &quot;totalBytes&quot;:[53.40580749511719,350.9521484375,350.9521484375,45.7763671875],
// &quot;collection&quot;:[&quot;FastCollect&quot;,&quot;Fastutil&quot;,&quot;KDS&quot;,&quot;Kotlin&quot;]
// },
// &quot;ggsize&quot;:{
// &quot;width&quot;:894.0,
// &quot;height&quot;:800.0
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;discrete&quot;:true,
// &quot;breaks&quot;:[],
// &quot;name&quot;:&quot;&quot;
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;name&quot;:&quot;Overhead (MB)&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;fill&quot;,
// &quot;values&quot;:[&quot;#ee6666&quot;,&quot;#5470c6&quot;,&quot;#3ba272&quot;,&quot;#9a60b4&quot;],
// &quot;name&quot;:&quot;&quot;,
// &quot;limits&quot;:[&quot;FastCollect&quot;,&quot;Fastutil&quot;,&quot;KDS&quot;,&quot;Kotlin&quot;]
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;numCollections&quot;,
// &quot;y&quot;:&quot;totalBytes&quot;,
// &quot;fill&quot;:&quot;collection&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;inherit_aes&quot;:false,
// &quot;position&quot;:&quot;dodge&quot;,
// &quot;geom&quot;:&quot;bar&quot;,
// &quot;data&quot;:{
// }
// }],
// &quot;data_meta&quot;:{
// &quot;series_annotations&quot;:[{
// &quot;type&quot;:&quot;str&quot;,
// &quot;column&quot;:&quot;numCollections&quot;
// },{
// &quot;type&quot;:&quot;float&quot;,
// &quot;column&quot;:&quot;totalBytes&quot;
// },{
// &quot;type&quot;:&quot;str&quot;,
// &quot;column&quot;:&quot;collection&quot;
// }]
// },
// &quot;spec_id&quot;:&quot;20&quot;
// };
//            fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing);
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &amp;&amp;
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &amp;&amp;
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive &amp;&amp; observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    &lt;/script>
//    &lt;/body>
// &lt;/html>"></iframe>            <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=6a1ecc44-771d-465a-8bbc-d5451d39d272 width="100%" height="100%" style="max-width: 894.0px; max-height: 800.0px;" viewBox="0 0 894.0 800.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pkq2O7X .plot-title {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #pkq2O7X .plot-subtitle {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pkq2O7X .plot-caption {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pkq2O7X .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
// font-style: normal;
//
// }
// #pkq2O7X .legend-title {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pkq2O7X .legend-item {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pkq2O7X .axis-title-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pkq2O7X .axis-text-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dZVA80H .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pkq2O7X .axis-title-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pkq2O7X .axis-text-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dZVA80H .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pkq2O7X .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pkq2O7X .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dZVA80H .tooltip-text {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dZVA80H .tooltip-title {
// fill: #474747;
// font-weight: bold;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dZVA80H .tooltip-label {
// fill: #474747;
// font-weight: bold;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pkq2O7X">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 800.0 L894.0 800.0 L894.0 0.0 Z">
//     </path>
//     <g transform="translate(21.0 22.0 ) ">
//       <g>
//         <g transform="translate(25.941816366404606 0.0 ) ">
//           <g>
//           </g>
//         </g>
//         <g transform="translate(25.941816366404606 0.0 ) ">
//           <g>
//             <line x1="0.0" y1="751.0" x2="726.0427250926342" y2="751.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="710.2401358178054" x2="726.0427250926342" y2="710.2401358178054" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="669.4802716356107" x2="726.0427250926342" y2="669.4802716356107" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill
